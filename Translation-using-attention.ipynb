# %% [markdown]
# # 1. Import Required Lib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Semester 7/Chinese/'
# Out:
# /content/drive/My Drive/Semester 7/Chinese

# %%
import pandas as pd
import numpy as np

import unicodedata
import string
import re
import random
from collections import Counter
import pickle
import random
import pdb
import logging
import itertools
import argparse
import time
import os
import math
import copy
import seaborn

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import optim
import torchtext
from torch.utils.data import BatchSampler
from torch.utils.data import SequentialSampler
from torch.utils.data import Sampler
from torch.optim.lr_scheduler import ReduceLROnPlateau

from bleu_score import BLEU_SCORE
from load_dataset_zh_wcharoption import *

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device('cuda')

# %% [markdown]
# # 2. Build data loaders

# %%
class Chinese(Dataset):
    def __init__(self, df, val = False):
        self.df = df
        self.val = val
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        english = self.df.iloc[idx,:]['en_idized']
        chin = self.df.iloc[idx,:]['zh_idized']
        en_len = self.df.iloc[idx,:]['en_len']
        zh_len = self.df.iloc[idx,:]['zh_len']
        if self.val:
            en_data = self.df.iloc[idx,:]['en_data'].lower()
            return [chin,english,zh_len,en_len,en_data]
        else:
            return [chin,english,zh_len,en_len]
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
def vocab_collate_func(batch):
    MAX_LEN_EN = 48
    MAX_LEN_zh = 48
    en_data = []
    zh_data = []
    en_len = []
    zh_len = []
    for datum in batch:
        en_len.append(datum[3])
        zh_len.append(datum[2])
    max_batch_length_en = max(en_len)
    max_batch_length_zh = max(zh_len)
    if max_batch_length_en < MAX_LEN_EN:
        MAX_LEN_EN = max_batch_length_en
    if max_batch_length_zh < MAX_LEN_zh:
        MAX_LEN_zh = max_batch_length_zh
    # padding
    for datum in batch:
        if datum[2]>MAX_LEN_zh:
            padded_vec_s1 = np.array(datum[0])[:MAX_LEN_zh]
        else:
            padded_vec_s1 = np.pad(np.array(datum[0]),
                                pad_width=((0,MAX_LEN_zh - datum[2])),
                                mode="constant", constant_values=PAD_IDX)
        if datum[3]>MAX_LEN_EN:
            padded_vec_s2 = np.array(datum[1])[:MAX_LEN_EN]
        else:
            padded_vec_s2 = np.pad(np.array(datum[1]),
                                pad_width=((0,MAX_LEN_EN - datum[3])),
                                mode="constant", constant_values=PAD_IDX)
        en_data.append(padded_vec_s2)
        zh_data.append(padded_vec_s1)
    zh_data = np.array(zh_data)
    en_data = np.array(en_data)
    zh_len = np.array(zh_len)
    en_len = np.array(en_len)

    zh_len[zh_len>MAX_LEN_zh] = MAX_LEN_zh
    en_len[en_len>MAX_LEN_EN] = MAX_LEN_EN
        
    return [torch.from_numpy(zh_data), torch.from_numpy(en_data),
            torch.from_numpy(zh_len), torch.from_numpy(en_len)]

def convert_idx_2_sent(tensor, lang_obj):
    word_list = []
    for i in tensor:
        if i.item() not in set([PAD_IDX,EOS_token,SOS_token]):
            word_list.append(lang_obj.index2word[i.item()])
    return (' ').join(word_list)

def convert_id_list_2_sent(list_idx, lang_obj):
    word_list = []
    if type(list_idx) == list:
        for i in list_idx:
            if i not in set([EOS_token]):
                word_list.append(lang_obj.index2word[i])
    else:
        for i in list_idx:
            if i.item() not in set([EOS_token,SOS_token,PAD_IDX]):
                word_list.append(lang_obj.index2word[i.item()])
    return (' ').join(word_list)

# %%
def vocab_collate_func_val(batch):
    return [torch.from_numpy(np.array(batch[0][0])).unsqueeze(0), torch.from_numpy(np.array(batch[0][1])).unsqueeze(0),
            torch.from_numpy(np.array(batch[0][2])).unsqueeze(0), torch.from_numpy(np.array(batch[0][3])).unsqueeze(0),batch[0][4]]

# %% [markdown]
# ## 2.1 Use character level Chinese or not

# %%
# MAX_LEN = 57
train,val,test,en_lang,zh_lang = train_val_load(57, "", './Data/', char=False)
# use character level Chinese
#train,val,test,en_lang,zh_lang = train_val_load(57, "", './Data/', char=True)

# %%
bs_dict = {'train':128,'validate':1, 'train_val':1,'val_train':128, 'test':1}
shuffle_dict = {'train':True,'validate':False, 'train_val':False,'val_train':True, 'test':False}

train_used = train
val_used = val

collate_fn_dict = {'train':vocab_collate_func, 'validate':vocab_collate_func_val,\
                   'train_val':vocab_collate_func_val,'val_train':vocab_collate_func,'test': vocab_collate_func_val}
transformed_dataset = {'train': Chinese(train_used),
                       'validate': Chinese(val_used, val = True),
                       'train_val':Chinese(train.iloc[:50], val = True),
                       'val_train':Chinese(val_used),
                       'test':Chinese(test, val= True)
                                               }
#'test':Chinese(test, val= True)

dataloader = {x: DataLoader(transformed_dataset[x], batch_size=bs_dict[x], collate_fn=collate_fn_dict[x],
                    shuffle=shuffle_dict[x], num_workers=0) for x in ['train', 'validate', 'train_val','val_train', 'test']}

# %% [markdown]
# # 3. Build Models

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, embed_dim, hidden_size,n_layers, rnn_type = 'lstm', device = 'cuda'):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = Embedding(input_size, embed_dim, PAD_IDX)
        self.rnn_type =  rnn_type
        self.dropout_in = nn.Dropout(p = 0.1)
        self.n_layers = n_layers
        self.device = device
        if rnn_type == 'gru':
            self.rnn = nn.GRU(embed_dim, hidden_size,batch_first=True,bidirectional=True, num_layers = self.n_layers, dropout = 0.2)
        elif rnn_type == 'lstm':
            self.rnn = LSTM(embed_dim, hidden_size, batch_first=True,bidirectional=True, num_layers = n_layers,dropout = 0.2)

    def forward(self, enc_inp, src_len):
        sorted_idx = torch.sort(src_len, descending=True)[1]
        orig_idx = torch.sort(sorted_idx)[1]
        embedded = self.embedding(enc_inp)
        bs = embedded.size(0)
        output = self.dropout_in(embedded)
        if self.rnn_type == 'gru':
            hidden =  self.initHidden(bs)
            sorted_output = output[sorted_idx]
            sorted_len = src_len[sorted_idx]
            packed_output = nn.utils.rnn.pack_padded_sequence(sorted_output, sorted_len.data.tolist(), batch_first = True)
            packed_outs, hiddden = self.rnn(packed_output,(hidden, c))
            hidden = hidden[:,orig_idx,:]
            output, _ = nn.utils.rnn.pad_packed_sequence(packed_outs, padding_value=PAD_IDX, batch_first = True)
            output = output[orig_idx]
            hidden = hidden.view(self.n_layers, 2, bs, -1).transpose(1, 2).contiguous().view(self.n_layers, bs, -1)
            return output, hidden, hidden
        elif self.rnn_type == 'lstm':
            hidden, c = self.initHidden(bs)
            sorted_output = output[sorted_idx]
            sorted_len = src_len[sorted_idx]
            packed_output = nn.utils.rnn.pack_padded_sequence(sorted_output, sorted_len.data.tolist(), batch_first = True)
            packed_outs, (hiddden, c) = self.rnn(packed_output,(hidden, c))
            hidden = hidden[:,orig_idx,:]
            c = c[:,orig_idx,:]
            output, _ = nn.utils.rnn.pad_packed_sequence(packed_outs, padding_value=PAD_IDX, batch_first = True)
            output = output[orig_idx]
            c = c.view(self.n_layers, 2, bs, -1).transpose(1, 2).contiguous().view(self.n_layers, bs, -1)
            hidden = hidden.view(self.n_layers, 2, bs, -1).transpose(1, 2).contiguous().view(self.n_layers, bs, -1)
            return output, hidden, c
        
    def initHidden(self,bs):
        if self.rnn_type == 'gru' :
            return torch.zeros(self.n_layers*2, bs, self.hidden_size).to(self.device)
        elif self.rnn_type == 'lstm':
            return torch.zeros(self.n_layers*2,bs,self.hidden_size).to(self.device),torch.zeros(self.n_layers*2,bs,self.hidden_size).to(self.device)

class Attention_Module(nn.Module):
    def __init__(self, hidden_dim, output_dim, device = 'cuda'):
        super(Attention_Module, self).__init__()
        self.l1 = Linear(hidden_dim, output_dim, bias = False)
        self.l2 = Linear(hidden_dim+output_dim, output_dim, bias =  False)
        self.device = device
        
    def forward(self, hidden, encoder_outs, src_lens):
        ''' hiddden: bsz x hidden_dim
        encoder_outs: bsz x sq_len x encoder dim (output_dim)
        src_lens: bsz
        
        x: bsz x output_dim
        attn_score: bsz x sq_len'''
        x = self.l1(hidden)
        att_score = (encoder_outs.transpose(0,1) * x.unsqueeze(0)).sum(dim = 2)
        seq_mask = sequence_mask(src_lens, max_len = max(src_lens).item(), device = self.device).transpose(0,1)
        masked_att = seq_mask*att_score
        masked_att[masked_att==0] = -1e10
        attn_scores = F.softmax(masked_att, dim=0)
        x = (attn_scores.unsqueeze(2) * encoder_outs.transpose(0,1)).sum(dim=0)
        x = torch.tanh(self.l2(torch.cat((x, hidden), dim=1)))
        return x, attn_scores
        
class AttentionDecoderRNN(nn.Module):
    def __init__(self, output_size, embed_dim, hidden_size, n_layers = 1, attention = True, device = 'cuda'):
        super(AttentionDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        encoder_output_size = hidden_size
        self.embedding = Embedding(output_size, embed_dim, PAD_IDX)
        self.dropout = nn.Dropout(p=0.1)
        self.n_layers = n_layers
        self.device = device
        self.att_layer = Attention_Module(self.hidden_size, encoder_output_size,self.device) if attention else None
        self.layers = nn.ModuleList([
            LSTMCell(
                input_size=self.hidden_size + embed_dim if ((layer == 0) and attention) else embed_dim if layer == 0 else hidden_size,
                hidden_size=hidden_size,
            )
            for layer in range(self.n_layers)
        ])
        self.fc_out = nn.Linear(self.hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
    def forward(self, dec_input,context_vector, prev_hiddens,prev_cs,encoder_outputs,src_len):
        bsz = dec_input.size(0)
        output = self.embedding(dec_input)
        output = self.dropout(output)
        if self.att_layer is not None:
            cated_input = torch.cat([output.squeeze(1),context_vector], dim = 1)
        else:
            cated_input = output.squeeze(1)
        new_hiddens = []
        new_cs = []
        for i, rnn in enumerate(self.layers):
            hidden, c = rnn(cated_input, (prev_hiddens[i], prev_cs[i]))
            cated_input = self.dropout(hidden)
            new_hiddens.append(hidden.unsqueeze(0))
            new_cs.append(c.unsqueeze(0))
        new_hiddens = torch.cat(new_hiddens, dim = 0)
        new_cs = torch.cat(new_cs, dim = 0)

        # apply attention using the last layer's hidden state
        if self.att_layer is not None:
            out, attn_score = self.att_layer(hidden, encoder_outputs, src_len)
        else:
            out = hidden
            attn_score = None
        context_vec = out
        out = self.dropout(out)
        out_vocab = self.softmax(self.fc_out(out))

        return out_vocab, context_vec, new_hiddens, new_cs, attn_score

# %% [markdown]
# # 4. Utilites functions, training and evaluation functions

# %%
def Embedding(num_embeddings, embedding_dim, padding_idx):
    m = nn.Embedding(num_embeddings, embedding_dim, padding_idx=padding_idx)
    nn.init.uniform_(m.weight, -0.1, 0.1)
    nn.init.constant_(m.weight[padding_idx], 0)
    return m


def LSTM(input_size, hidden_size, **kwargs):
    m = nn.LSTM(input_size, hidden_size,**kwargs)
    for name, param in m.named_parameters():
        if 'weight' in name or 'bias' in name:
            param.data.uniform_(-0.1, 0.1)
    return m


def LSTMCell(input_size, hidden_size, **kwargs):
    m = nn.LSTMCell(input_size, hidden_size,**kwargs)
    for name, param in m.named_parameters():
        if 'weight' in name or 'bias' in name:
            param.data.uniform_(-0.1, 0.1)
    return m


def Linear(in_features, out_features, bias=True, dropout=0):
    """Linear layer (input: N x T x C)"""
    m = nn.Linear(in_features, out_features, bias=bias)
    m.weight.data.uniform_(-0.1, 0.1)
    if bias:
        m.bias.data.uniform_(-0.1, 0.1)
    return m

# %%
def sequence_mask(sequence_length, max_len=None, device = 'cuda'):
    if max_len is None:
        max_len = sequence_length.max().item()
    batch_size = sequence_length.size(0)
    seq_range = torch.arange(0, max_len).long()
    seq_range_expand = seq_range.unsqueeze(0).repeat([batch_size,1])
    seq_range_expand = seq_range_expand.to(device)
    seq_length_expand = (sequence_length.unsqueeze(1)
                         .expand_as(seq_range_expand))
    return (seq_range_expand < seq_length_expand).float()

# %%
def encode_decode(encoder,decoder,data_en,data_de,src_len,tar_len,rand_num = 0.95, val = False):
    if not val:
        use_teacher_forcing = True if random.random() < rand_num else False
    #     print("tar_len",tar_len)
        bss = data_en.size(0)
        en_out,en_hid,en_c = encoder(data_en, src_len)
        max_src_len_batch = max(src_len).item()
        max_tar_len_batch = max(tar_len).item()
        prev_hiddens = en_hid
        prev_cs = en_c
        decoder_input = torch.tensor([[SOS_token]]*bss).to(device)
        prev_output = torch.zeros((bss, en_out.size(-1))).to(device)
        if use_teacher_forcing:
            d_out = []
            for i in range(max_tar_len_batch):
                out_vocab, prev_output,prev_hiddens, prev_cs, attention_score = decoder(decoder_input,prev_output, \
                                                                                        prev_hiddens,prev_cs, en_out,\
                                                                                        src_len)
                d_out.append(out_vocab.unsqueeze(-1))
                decoder_input = data_de[:,i].view(-1,1)
            d_out = torch.cat(d_out,dim=-1)
        else:
            d_out = []
            for i in range(max_tar_len_batch):
                out_vocab, prev_output,prev_hiddens, prev_cs, attention_score = decoder(decoder_input,prev_output, \
                                                                                        prev_hiddens,prev_cs, en_out,\
                                                                                        src_len)
                d_out.append(out_vocab.unsqueeze(-1))
                topv, topi = out_vocab.topk(1)
                decoder_input = topi.squeeze().detach().view(-1,1)
            d_out = torch.cat(d_out,dim=-1)
        return d_out
    else:
        encoder.eval()
        decoder.eval()
        bss = data_en.size(0)
        en_out,en_hid,en_c = encoder(data_en, src_len)
        max_src_len_batch = max(src_len).item()
        max_tar_len_batch = max(tar_len).item()
        prev_hiddens = en_hid
        prev_cs = en_c
        decoder_input = torch.tensor([[SOS_token]]*bss).to(device)
        prev_output = torch.zeros((bss, en_out.size(-1))).to(device)
        d_out = []
        for i in range(max_tar_len_batch):
            out_vocab, prev_output,prev_hiddens, prev_cs, attention_score = decoder(decoder_input,prev_output, \
                                                                                    prev_hiddens,prev_cs, en_out,\
                                                                                    src_len)
            d_out.append(out_vocab.unsqueeze(-1))
            topv, topi = out_vocab.topk(1)
            decoder_input = topi.squeeze().detach().view(-1,1)
        d_out = torch.cat(d_out,dim=-1)
        return d_out

# %%
def flatten_cel_loss(input,target,nll):
    input = input.transpose(1,2)
    bs, sl = input.size()[:2]
    return nll(input.contiguous().view(bs*sl,-1),target.contiguous().view(-1))

# %%
def validation_new(encoder, decoder, val_dataloader, lang_en,lang_zh,m_type, verbose = False, replace_unk = False):
    encoder.eval()
    decoder.eval()
    pred_corpus = []
    true_corpus = []
    src_corpus = []
    running_loss = 0
    running_total = 0
    bl = BLEU_SCORE()
    attention_scores_for_all_val = []
    for data in val_dataloader:
        encoder_i = data[0].to(device)
        src_len = data[2].to(device)
        bs,sl = encoder_i.size()[:2]
        en_out,en_hid,en_c = encoder(encoder_i,src_len)
        max_src_len_batch = max(src_len).item()
        prev_hiddens = en_hid
        prev_cs = en_c
        decoder_input = torch.tensor([[SOS_token]]*bs).to(device)
        prev_output = torch.zeros((bs, en_out.size(-1))).to(device)
        d_out = []
        attention_scores = []
        for i in range(sl*2):
            out_vocab, prev_output,prev_hiddens, prev_cs, attention_score = decoder(decoder_input,prev_output, \
                                                                                    prev_hiddens,prev_cs, en_out,\
                                                                                    src_len)
            topv, topi = out_vocab.topk(1)
            d_out.append(topi.item())
            decoder_input = topi.squeeze().detach().view(-1,1)
            if m_type == 'attention':
                attention_scores.append(attention_score.unsqueeze(-1))
            if topi.item() == EOS_token:
                break
        
        if replace_unk:
            true_sent = convert_id_list_2_sent(data[1][0],lang_en)
            true_corpus.append(true_sent)
        else:
            true_corpus.append(data[-1])
        src_sent = convert_id_list_2_sent(data[0][0],lang_zh)
        src_corpus.append(src_sent)
        pred_sent = convert_id_list_2_sent(d_out,lang_en)
        pred_corpus.append(pred_sent)
        if m_type == 'attention':
            attention_scores = torch.cat(attention_scores, dim = -1)
            attention_scores_for_all_val.append(attention_scores)
        if verbose:
            print("True Sentence:",data[-1])
            print("Pred Sentence:", pred_sent)
            print('-*'*50)
    score = bl.corpus_bleu(pred_corpus,[true_corpus],lowercase=True)[0]
    return score, attention_scores_for_all_val, pred_corpus, src_corpus

# %%
def validation_beam_search(encoder, decoder, val_dataloader,lang_en,lang_zh,m_type, beam_size, verbose = False,\
                           device = 'cuda', replace_unk = False):
    encoder.eval()
    decoder.eval()
    encoder = encoder.to(device)
    decoder = decoder.to(device)
    pred_corpus = []
    true_corpus = []
    src_corpus = []
    running_loss = 0
    running_total = 0
    bl = BLEU_SCORE()
    j = 0
    attention_scores_for_all_val = []
    for data in val_dataloader:
#         print(j)
        encoder_i = data[0].to(device)
        src_len = data[2].to(device)
        bs,sl = encoder_i.size()[:2]
        en_out,en_hid,en_c = encoder(encoder_i,src_len)
        max_src_len_batch = max(src_len).item()
        prev_hiddens = en_hid
        prev_cs = en_c
        decoder_input = torch.tensor([[SOS_token]]*bs).to(device)
        prev_output = torch.zeros((bs, en_out.size(-1))).to(device)
        list_decoder_input = [None]*beam_size
        beam_stop_flags = [False]*beam_size
        beam_score = torch.zeros((bs,beam_size))
        list_d_outs = [[] for _ in range(beam_size)]
        select_beam_size = beam_size
        attention_scores = [[] for _ in range(beam_size)]
        for i in range(sl+20):
            if i == 0:
                out_vocab, prev_output,prev_hiddens, prev_cs, attention_score = decoder(decoder_input,prev_output, \
                                                                                    prev_hiddens,prev_cs, en_out,\
                                                                                    src_len)
                bss, vocab_size = out_vocab.size()
                topv, topi = out_vocab.topk(beam_size)
                list_prev_output = [prev_output]*beam_size
                list_prev_hiddens = [prev_hiddens]*beam_size
                list_prev_cs = [prev_cs]*beam_size
                for b in range(beam_size):
                    beam_score[0][b] = topv[0][b].item()
                    list_decoder_input[b] = topi[0][b].squeeze().detach().view(-1,1)
                    list_d_outs[b].append(topi[0][b].item())
                    if m_type == 'attention':
                        attention_scores[b].append(attention_score.unsqueeze(-1))
                    if topi[0][b].item() == EOS_token:
                        beam_stop_flags[b] = True
            else:
                beam_out_vocab = [None]*beam_size
                temp_out = [None]*beam_size
                temp_hid = [None]*beam_size
                temp_c = [None]*beam_size
                temp_attention_score = [[] for _ in range(beam_size)]
                prev_d_outs = copy.deepcopy(list_d_outs)
                for b in range(beam_size):
                    if not beam_stop_flags[b]:
                        beam_out_vocab[b], temp_out[b], temp_hid[b], temp_c[b], temp_attention_score[b] =\
                            decoder(list_decoder_input[b],list_prev_output[b],list_prev_hiddens[b],list_prev_cs[b],\
                                    en_out,src_len)
                        beam_out_vocab[b] = beam_out_vocab[b] + beam_score[0][b]
                    if beam_stop_flags[b]:
                        beam_out_vocab[b] = torch.zeros(bss,vocab_size).fill_(float('-inf')).to(device)
                beam_out_vocab = torch.cat(beam_out_vocab,dim = 1)
                
                topv, topi = beam_out_vocab.topk(beam_size)
                id_for_hid = topi//vocab_size
                topi_idx = topi%vocab_size
                for b in range(beam_size):
                    if not beam_stop_flags[b]:
                        beam_score[0][b] = topv[0][b].item()
                        list_decoder_input[b] = topi_idx[0][b].squeeze().detach().view(-1,1)
                        list_d_outs[b] = copy.deepcopy(prev_d_outs[id_for_hid[0][b]])
                        list_d_outs[b].append(topi_idx[0][b].item())
                        if m_type == 'attention':
                            attention_scores[b].append(temp_attention_score[b].unsqueeze(-1))
                        if topi_idx[0][b].item() == EOS_token:
                            beam_stop_flags[b] = True
                        else:
                            list_prev_output[b] = temp_out[id_for_hid[0][b]]
                            list_prev_hiddens[b] = temp_hid[id_for_hid[0][b]]
                            list_prev_cs[b] = temp_c[id_for_hid[0][b]]
                if all(beam_stop_flags):
                    break
        id_max_score = np.argmax(beam_score)
        d_out = list_d_outs[id_max_score]
        if m_type == 'attention':
            att_score = attention_scores[id_max_score]
            att_score = torch.cat(att_score, dim = -1)
            attention_scores_for_all_val.append(att_score)
        if replace_unk:
            true_sent = convert_id_list_2_sent(data[1][0],lang_en)
            true_corpus.append(true_sent)
        else:
            true_corpus.append(data[-1])
        pred_sent = convert_id_list_2_sent(d_out,lang_en)
        pred_corpus.append(pred_sent)
        src_sent = convert_id_list_2_sent(data[0][0], lang_zh)
        src_corpus.append(src_sent)
        if verbose:
            print("Source Sentence:",src_sent)
            print("True Sentence:",data[-1])
            print("Pred Sentence:", pred_sent)
            print('-*'*50)
    score = bl.corpus_bleu(pred_corpus,[true_corpus],lowercase=True)[0]
    return score, attention_scores_for_all_val, pred_corpus, src_corpus

# %%
def train_model(encoder_optimizer,decoder_optimizer, encoder, decoder, loss_fun,m_type, dataloader, en_lang,zh_lang,\
                num_epochs=60, val_every = 1, train_bleu_every = 10,clip = 0.1, rm = 0.8, enc_scheduler = None,\
               dec_scheduler = None, enc_dec_fn = encode_decode, val_fn = validation_new):
    best_score = 0
    best_bleu = 0
    loss_hist = {'train': [], 'val_train': []}
    bleu_hist = {'train': [], 'validate': []}
    best_encoder_wts = None
    best_decoder_wts = None
    phases = ['train','val_train']
    for epoch in range(num_epochs):
        for ex, phase in enumerate(phases):
            start = time.time()
            total = 0
            top1_correct = 0
            running_loss = 0
            running_total = 0
            if phase == 'train':
                encoder.train()
                decoder.train()
            else:
                encoder.eval()
                decoder.eval()
            for data in dataloader[phase]:
                encoder_optimizer.zero_grad()
                decoder_optimizer.zero_grad()

                encoder_i = data[0].to(device)
                decoder_i = data[1].to(device)
                src_len = data[2].to(device)
                tar_len = data[3].to(device)
                if phase == 'val_train':  
                    out = enc_dec_fn(encoder,decoder,encoder_i,decoder_i,src_len,tar_len,rand_num=rm,val = True )
                else:
                    out = enc_dec_fn(encoder,decoder,encoder_i,decoder_i,src_len,tar_len,rand_num=rm,val = False )
                N = decoder_i.size(0)
                loss = loss_fun(out.float(), decoder_i.long())
                running_loss += loss.item() * N
                
                total += N
                if phase == 'train':
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
                    torch.nn.utils.clip_grad_norm_(decoder.parameters(), clip)
                    encoder_optimizer.step()
                    decoder_optimizer.step()
                    
            epoch_loss = running_loss / total 
            loss_hist[phase].append(epoch_loss)
            print("epoch {} {} loss = {}, time = {}".format(epoch, phase, epoch_loss,
                                                                           time.time() - start))
        if (enc_scheduler is not None) and (dec_scheduler is not None):
            enc_scheduler.step(loss_hist['train'][-1])
            dec_scheduler.step(loss_hist['train'][-1])
        if epoch%val_every == 0:
            val_bleu_score, _,_,_ = val_fn(encoder,decoder,dataloader['validate'],\
                                                                               en_lang,zh_lang,m_type, verbose=False, \
                                                                               replace_unk=True)
            bleu_hist['validate'].append(val_bleu_score)
            print("validation BLEU = ", val_bleu_score)
            if val_bleu_score > best_bleu:
                best_bleu = val_bleu_score
                best_encoder_wts = encoder.state_dict()
                best_decoder_wts = decoder.state_dict()
        print('='*50)
    encoder.load_state_dict(best_encoder_wts)
    decoder.load_state_dict(best_decoder_wts)
    print("Training completed. Best BLEU is {}".format(best_bleu))
    return encoder,decoder,loss_hist,bleu_hist

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
seaborn.set_style("darkgrid",{"Droid Sans Fallback":['simhei', 'Arial']})

# %%
def draw(att_mat, x, y):
    x = x.split(' ')
    y = y.split(' ')
    x += ['EOS']
    y += ['EOS']
    att_mat = att_mat.data.cpu().squeeze(1).numpy()
    seaborn.heatmap(att_mat, 
                    xticklabels=x, square=True, yticklabels=y, vmin=0.0, vmax=1.0, 
                    cbar=False)

# %% [markdown]
# # 5. Without attention (Training and Evaluation)

# %%
encoder_wo_att = EncoderRNN(zh_lang.n_words,512,512, 1).to(device)
decoder_wo_att = AttentionDecoderRNN(en_lang.n_words,512,1024,n_layers=1, attention = False).to(device)
print("Encoder model")
print(encoder_wo_att)
print("Decoder model")
decoder_wo_att
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:51: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
# encoder_optimizer = optim.Adam(encoder_wo_att.parameters(), lr = 5e-3)
# decoder_optimizer = optim.Adam(decoder_wo_att.parameters(), lr = 5e-3)
encoder_optimizer = optim.SGD(encoder_wo_att.parameters(), lr=0.25,nesterov=True, momentum = 0.99)
enc_scheduler = ReduceLROnPlateau(encoder_optimizer, min_lr=1e-4,factor = 0.5,  patience=0)
decoder_optimizer = optim.SGD(decoder_wo_att.parameters(), lr=0.25,nesterov=True, momentum = 0.99)
dec_scheduler = ReduceLROnPlateau(decoder_optimizer, min_lr=1e-4,factor = 0.5,  patience=0)

criterion = nn.CrossEntropyLoss()

# %%
import torch
dir(torch.nn)

# %%
encoder_wo_att, decoder_wo_att, loss_hist, acc_hist = train_model(encoder_optimizer, decoder_optimizer, encoder_wo_att, decoder_wo_att, criterion,\
                                            "non_attention", dataloader,en_lang,zh_lang, num_epochs = 15, rm = 0.95,\
                                           enc_scheduler = enc_scheduler, dec_scheduler = dec_scheduler)
# Out:
# epoch 0 train loss = 2.4860232951307153, time = 3385.71778011322
# epoch 0 val_train loss = 3.5251828366853624, time = 9.526296615600586
# validation BLEU =  1.3840768062523936
# ==================================================
# epoch 1 train loss = 1.960187975888975, time = 3378.924038887024
# epoch 1 val_train loss = 3.3426652975634483, time = 9.57643985748291
# validation BLEU =  1.7440558816783263
# ==================================================
# epoch 2 train loss = 1.8164858315747296, time = 3366.1972584724426
# epoch 2 val_train loss = 3.022067629846668, time = 9.532869338989258
# validation BLEU =  1.7263314605569298
# ==================================================
# epoch 3 train loss = 1.7120166643682078, time = 3370.0292069911957
# epoch 3 val_train loss = 3.1412299607690604, time = 9.600884437561035
# validation BLEU =  2.1538558099282765
# ==================================================
# epoch 4 train loss = 1.6242764046311289, time = 3393.692474126816
# epoch 4 val_train loss = 3.033955384775535, time = 9.832443475723267
# validation BLEU =  3.301393790616432
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-be8f68dc41b9> in <module>()
# ----> 1 encoder_wo_att, decoder_wo_att, loss_hist, acc_hist = train_model(encoder_optimizer, decoder_optimizer, encoder_wo_att, decoder_wo_att, criterion,                                            "non_attention", dataloader,en_lang,zh_lang, num_epochs = 15, rm = 0.95,                                           enc_scheduler = enc_scheduler, dec_scheduler = dec_scheduler)
#
# <ipython-input-40-86a972ce5d37> in train_model(encoder_optimizer, decoder_optimizer, encoder, decoder, loss_fun, m_type, dataloader, en_lang, zh_lang, num_epochs, val_every, train_bleu_every, clip, rm, enc_scheduler, dec_scheduler, enc_dec_fn, val_fn)
#      34                 N = decoder_i.size(0)
#      35                 loss = loss_fun(out.float(), decoder_i.long())
# ---> 36                 running_loss += loss.item() * N
#      37
#      38                 total += N
#
# KeyboardInterrupt:

# %%
torch.save(encoder_wo_att.state_dict(), 'lstm_wo_att_enc_1_layer.pth')
torch.save(decoder_wo_att.state_dict(), 'lstm_wo_att_dec_1_layer.pth')

# %% [markdown]
# ## Evaluation using BLEU with beam size 3

# %%
bleu_3_no_unk, att_score_wo, pred_wo, src_wo = validation_beam_search(encoder_wo_att, decoder_wo_att,dataloader['validate'],en_lang,\
                                                                      zh_lang, 'no_attention',3,verbose=True)
# Out:
# True Sentence: when i was 11 , i remember waking up one morning to the sound of joy in my house .
# Pred Sentence: and i went back to my mother , and i went back to my mother , and i went back to the house .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: my father was listening to bbc news on his small , gray radio .
# Pred Sentence: and my father , my mother , his mother , the UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: there was a big smile on his face which was unusual then , because the news mostly depressed him .
# Pred Sentence: he &apos;s got a little bit of his life , and he &apos;s not going to , he &apos;s , . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: &quot; the taliban are gone ! &quot; my father shouted .
# Pred Sentence: UKN : UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i didn &apos;t know what it meant , but i could see that my father was very , very happy .
# Pred Sentence: i don &apos;t know , but i don &apos;t think that &apos;s a good thing .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: &quot; you can go to a real school now , &quot; he said .
# Pred Sentence: and you can see that , you know , it &apos;s a little PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: a morning that i will never forget .
# Pred Sentence: i don &apos;t know , i don &apos;t know .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: a real school .
# Pred Sentence: one of them .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you see , i was six when the taliban took over afghanistan and made it illegal for girls to go to school .
# Pred Sentence: and i was in a UKN , UKN UKN , and , . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so for the next five years , i dressed as a boy to escort my older sister , who was no longer allowed to be outside alone , to a secret school .
# Pred Sentence: so in that time , i went to my mother , and i went back to the house , and i was a little girl , and i was a little PAD PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: it was the only way we both could be educated .
# Pred Sentence: this is what we &apos;re doing .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: each day , we took a different route so that no one would suspect where we were going .
# Pred Sentence: we can &apos;t see if we &apos;re going to , and we , , to PAD , . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence:
, PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and we said to the zambians , &quot; my god , the hippos ! &quot;
# Pred Sentence: we &apos;ve got to go back to the UKN , and they &apos;re going to PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and the zambians said , &quot; yes , that &apos;s why we have no agriculture here . &quot;
# Pred Sentence: and the third thing , if we say , &quot; this is what we know .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: &quot; why didn &apos;t you tell us ? &quot; &quot; you never asked . &quot;
# Pred Sentence: why ? you know , you don &apos;t know what you &apos;re doing .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i thought it was only us italians blundering around africa , but then i saw what the americans were doing , what the english were doing , what the french were doing , and after seeing what they were doing , i became quite proud of our project in zambia .
# Pred Sentence: i &apos;m not going to talk about , but i &apos;m going to , but we , , , , , , , , , , , , , , , , , , the , , , , , , , we , , PAD , , PAD PAD , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: because , you see , at least we fed the hippos .
# Pred Sentence: because we &apos;re not going to be PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you should see the rubbish — -- you should see the rubbish that we have bestowed on unsuspecting african people .
# Pred Sentence: and you can see , as you can see , we &apos;re going to , and we , to , , to PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you want to read the book , read &quot; dead aid , &quot; by dambisa moyo , zambian woman economist .
# Pred Sentence: and you can see , this is a UKN UKN , UKN UKN , UKN the . PAD . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the book was published in 2009 .
# Pred Sentence: and this is the last time .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we western donor countries have given the african continent two trillion american dollars in the last 50 years .
# Pred Sentence: and we &apos;ve been working on this project , and we &apos;ve been working in the united states , in the u.s.
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i &apos;m not going to tell you the damage that that money has done .
# Pred Sentence: i don &apos;t want to go back to my house .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: just go and read her book .
# Pred Sentence: you can see what you can do .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: read it from an african woman , the damage that we have done .
# Pred Sentence: you know , the last two years ago , we &apos;ve been working on the planet .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we western people are imperialist , colonialist missionaries , and there are only two ways we deal with people : we either patronize them , or we are paternalistic .
# Pred Sentence: we &apos;ve got to UKN UKN , UKN , UKN , UKN , UKN , UKN , UKN UKN , UKN , and we , , , , we , , , PAD PAD , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the two words come from the latin root &quot; pater , &quot; which means &quot; father . &quot;
# Pred Sentence: so this is a UKN , UKN UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: but they mean two different things .
# Pred Sentence: but there &apos;s a little bit of that .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: paternalistic , i treat anybody from a different culture as if they were my children . &quot; i love you so much . &quot;
# Pred Sentence: and then , i &apos;ve been working with a lot of people , and i &apos;m going to PAD , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: patronizing , i treat everybody from another culture as if they were my servants .
# Pred Sentence: and that &apos;s what i want to talk about today , and i &apos;m going to PAD PAD . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: that &apos;s why the white people in africa are called &quot; bwana , &quot; boss .
# Pred Sentence: and that &apos;s why it &apos;s not the same thing , and it &apos;s PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i was given a slap in the face reading a book , &quot; small is beautiful , &quot; written by schumacher , who said , above all in economic development , if people do not wish to be helped , leave them alone .
# Pred Sentence: and i went to the last two months , and i went to the UKN , and he said , &quot; and , &quot; and , the , , the , , , , , , , the , , , , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: this should be the first principle of aid .
# Pred Sentence: that &apos;s not the same thing .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the first principle of aid is respect .
# Pred Sentence: what &apos;s happening in the world ?
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: this morning , the gentleman who opened this conference lay a stick on the floor , and said , &quot; can we -- can you imagine a city that is not neocolonial ? &quot;
# Pred Sentence: now , for example , this is a UKN UKN , and if you look at the UKN , we &apos;re going to , and we , , to , , , , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i decided when i was 27 years old to only respond to people , and i invented a system called enterprise facilitation , where you never initiate anything , you never motivate anybody , but you become a servant of the local passion , the servant of local people who have a dream to become a better person .
# Pred Sentence: for years , i &apos;ve been working with a few years ago , and i &apos;m going to talk about , and we , and , to , , to , , to , , to , , , , , to , , , , we , , PAD , , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so what you do -- you shut up .
# Pred Sentence: so what do we do with this ?
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you never arrive in a community with any ideas , and you sit with the local people .
# Pred Sentence: and we have to go back to the UKN , and we can &apos;t , , to PAD , to PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we don &apos;t work from offices .
# Pred Sentence: our lives are not going to be .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we meet at the cafe . we meet at the pub .
# Pred Sentence: we &apos;re going to go to the UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we have zero infrastructure .
# Pred Sentence: we don &apos;t need to change the world .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and what we do , we become friends , and we find out what that person wants to do .
# Pred Sentence: and what we did was , what they did was , they had to go back to the UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the most important thing is passion .
# Pred Sentence: the problem is , the problem is .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you can give somebody an idea .
# Pred Sentence: you can see what you can do .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: if that person doesn &apos;t want to do it , what are you going to do ?
# Pred Sentence: but if you have to do something , you can do something .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the passion that the person has for her own growth is the most important thing .
# Pred Sentence: it &apos;s not the same thing that &apos;s going to PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the passion that that man has for his own personal growth is the most important thing .
# Pred Sentence: what &apos;s happening is that the most important thing is , the is the PAD . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and then we help them to go and find the knowledge , because nobody in the world can succeed alone .
# Pred Sentence: and then we thought , &quot; well , we need to be able to create a UKN , and , to PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the person with the idea may not have the knowledge , but the knowledge is available .
# Pred Sentence: it &apos;s not the same way , but we can &apos;t even be there .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so years and years ago , i had this idea : why don &apos;t we , for once , instead of arriving in the community to tell people what to do , why don &apos;t , for once , listen to them ? but not in community meetings .
# Pred Sentence: so i &apos;ve been working with a lot of time , but i &apos;m going to , but we , , we , , we , , , , we , , we , , , PAD we , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: let me tell you a secret .
# Pred Sentence: i &apos;m going to tell you .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: there is a problem with community meetings .
# Pred Sentence: and there &apos;s a problem .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: entrepreneurs never come , and they never tell you , in a public meeting , what they want to do with their own money , what opportunity they have identified .
# Pred Sentence: they don &apos;t want to be a little bit , and if they &apos;re going to , and they , , they , , , , , , PAD , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so planning has this blind spot .
# Pred Sentence: so there &apos;s a big thing .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the smartest people in your community you don &apos;t even know , because they don &apos;t come to your public meetings .
# Pred Sentence: you don &apos;t have to have a lot of money , but you don &apos;t know what &apos;s going to be PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: what we do , we work one-on-one , and to work one-on-one , you have to create a social infrastructure that doesn &apos;t exist .
# Pred Sentence: we &apos;re going to be UKN , and we , and we , , we , , , we we , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you have to create a new profession .
# Pred Sentence: we need to make a difference .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the profession is the family doctor of enterprise , the family doctor of business , who sits with you in your house , at your kitchen table , at the cafe , and helps you find the resources to transform your passion into a way to make a living .
# Pred Sentence: and this is a little bit of a UKN , , and , , , the , , , , the , , , , , , , the , , , , , , , the , , , PAD , , PAD , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i started this as a tryout in esperance , in western australia .
# Pred Sentence: i &apos;ve been working with a UKN in the UKN of a UKN
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i was a doing a ph.d. at the time , trying to go away from this patronizing bullshit that we arrive and tell you what to do .
# Pred Sentence: and i realized that there was a little bit like a UKN , and , a , . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and so what i did in esperance that first year was to just walk the streets , and in three days i had my first client , and i helped this first guy who was smoking fish from a garage , was a maori guy , and i helped him to sell to the restaurant in perth , to get organized , and then the fishermen came to me to say , &quot; you the guy who helped maori ? can you help us ? &quot;
# Pred Sentence: and i was in a UKN with a UKN , and , and , , , a , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the , , , , , , , , , , , , , , , , , , , , , , PAD , , , PAD , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and i helped these five fishermen to work together and get this beautiful tuna not to the cannery in albany for 60 cents a kilo , but we found a way to take the fish for sushi to japan for 15 dollars a kilo , and the farmers came to talk to me , said , &quot; hey , you helped them . can you help us ? &quot;
# Pred Sentence: so i &apos;m going to take a little bit of a UKN , and i , , , , a to , , , to , , , , , , , , , , , , , , to , , , , , to , , , , , , PAD , , PAD , , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: in a year , i had 27 projects going on , and the government came to see me to say , &quot; how can you do that ?
# Pred Sentence: and after that , i &apos;ve been working with a few years ago , and what i &apos;m going to talk about PAD is PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: how can you do — ? &quot; and i said , &quot; i do something very , very , very difficult .
# Pred Sentence: you can see what i &apos;m going to talk about .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i shut up , and listen to them . &quot;
# Pred Sentence: that &apos;s what they say .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so — — so the government says , &quot; do it again . &quot;
# Pred Sentence: so , what do you do ?
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we &apos;ve done it in 300 communities around the world .
# Pred Sentence: and we &apos;ve been working on this project , and we &apos;ve been working on this project .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we have helped to start 40,000 businesses .
# Pred Sentence: we &apos;ve got to go out of the world .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: there is a new generation of entrepreneurs who are dying of solitude .
# Pred Sentence: UKN , UKN , UKN , UKN , UKN , UKN PAD . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: peter drucker , one of the greatest management consultants in history , died age 96 , a few years ago .
# Pred Sentence: UKN UKN : the UKN of the united states , the UKN of the UKN
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: peter drucker was a professor of philosophy before becoming involved in business , and this is what peter drucker says : &quot; planning is actually incompatible with an entrepreneurial society and economy . &quot;
# Pred Sentence: UKN UKN UKN , who is a UKN , UKN UKN , the UKN of the , the the , , the the PAD , PAD the PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: planning is the kiss of death of entrepreneurship .
# Pred Sentence: it &apos;s a UKN , UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so now you &apos;re rebuilding christchurch without knowing what the smartest people in christchurch want to do with their own money and their own energy .
# Pred Sentence: now , we &apos;ve been working with a lot of time , and we , , and , , , , PAD , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you have to learn how to get these people to come and talk to you .
# Pred Sentence: we need to know what they want to do .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you have to offer them confidentiality , privacy , you have to be fantastic at helping them , and then they will come , and they will come in droves .
# Pred Sentence: we don &apos;t need to be able to get them to them , and they &apos;re going to , and we , , we , , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: in a community of 10,000 people , we get 200 clients .
# Pred Sentence: there &apos;s a number of people in the united states , and we &apos;re going to PAD PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: can you imagine a community of 400,000 people , the intelligence and the passion ?
# Pred Sentence: you can have an opportunity to be able to do with a little bit of PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: which presentation have you applauded the most this morning ?
# Pred Sentence: and the third thing that you have to do is to you .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# ...
# True Sentence: and i refuse to be a part of this manufactured reality that was manufactured for me by some other people , and i &apos;m manufacturing my own reality .
# Pred Sentence: i &apos;m going to talk about my life , and i &apos;m going to PAD the PAD , i &apos;m going to
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: see , i &apos;m an artist .
# Pred Sentence: so i &apos;m going to show you an example .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: gardening is my graffiti . i grow my art .
# Pred Sentence: and that &apos;s what i did with my life .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: if kids grow kale , kids eat kale .
# Pred Sentence: and if they &apos;re going to go back to school , they &apos;re going to go .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: if they grow tomatoes , they eat tomatoes .
# Pred Sentence: and if they can &apos;t do it , they can do it .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: but when none of this is presented to them , if they &apos;re not shown how food affects the mind and the body , they blindly eat whatever the hell you put in front of them .
# Pred Sentence: but when they do that , they don &apos;t know what they &apos;re doing , but they don &apos;t know what they &apos;re going to do , but they &apos;re going to , and , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i see young people and they want to work , but they &apos;re in this thing where they &apos;re caught up -- i see kids of color and they &apos;re just on this track that &apos;s designed for them , that leads them to nowhere .
# Pred Sentence: and i realized that they had a lot of people , and they were , and they were , and they were , and they , but they , but , they , , they , , , , , , PAD PAD , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so with gardening , i see an opportunity where we can train these kids to take over their communities , to have a sustainable life .
# Pred Sentence: and when i was doing , i started with a lot of time , and we , and we , and we , , , , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and when we do this , who knows ?
# Pred Sentence: we &apos;re going to do that . we don &apos;t know .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we might produce the next george washington carver .
# Pred Sentence: it &apos;s a UKN UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: but if we don &apos;t change the composition of the soil , we will never do this .
# Pred Sentence: but if we don &apos;t want to be able to do that , we don &apos;t .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: now this is one of my plans . this is what i want to do .
# Pred Sentence: and that &apos;s what i &apos;m going to talk about today .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i want to plant a whole block of gardens where people can share in the food in the same block .
# Pred Sentence: and i &apos;m going to talk to you about a lot of people in the world .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i want to take shipping containers and turn them into healthy cafes .
# Pred Sentence: i want to go to the UKN and the UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: now don &apos;t get me wrong .
# Pred Sentence: there &apos;s no way .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i &apos;m not talking about no free shit , because free is not sustainable .
# Pred Sentence: and i don &apos;t think it &apos;s not a UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the funny thing about sustainability , you have to sustain it .
# Pred Sentence: and this is the same thing that &apos;s going on , and the PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: what i &apos;m talking about is putting people to work , and getting kids off the street , and letting them know the joy , the pride and the honor in growing your own food , opening farmer &apos;s markets .
# Pred Sentence: and what i &apos;m going to tell you is that they &apos;re not going to , and to , to , to , to , to , to PAD , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so what i want to do here , we gotta make this sexy .
# Pred Sentence: so what i want to talk about is that this is a little bit of what &apos;s going on .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so i want us all to become ecolutionary renegades , gangstas , gangsta gardeners .
# Pred Sentence: and i think we should be able to create a new world .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-e458161a5eab> in <module>()
# ----> 1 bleu_3_no_unk, att_score_wo, pred_wo, src_wo = validation_beam_search(encoder_wo_att, decoder_wo_att,dataloader['validate'],en_lang,                                                                      zh_lang, 'no_attention',3,verbose=True)
#
# <ipython-input-46-15ede751d95b> in validation_beam_search(encoder, decoder, val_dataloader, lang_en, lang_zh, m_type, beam_size, verbose, device, replace_unk)
#      54                 for b in range(beam_size):
#      55                     if not beam_stop_flags[b]:
# ---> 56                         beam_out_vocab[b], temp_out[b], temp_hid[b], temp_c[b], temp_attention_score[b] =                            decoder(list_decoder_input[b],list_prev_output[b],list_prev_hiddens[b],list_prev_cs[b],                                    en_out,src_len)
#      57                         beam_out_vocab[b] = beam_out_vocab[b] + beam_score[0][b]
#      58                     if beam_stop_flags[b]:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-11-99cef6e9fb2f> in forward(self, dec_input, context_vector, prev_hiddens, prev_cs, encoder_outputs, src_len)
#     106         for i, rnn in enumerate(self.layers):
#     107             hidden, c = rnn(cated_input, (prev_hiddens[i], prev_cs[i]))
# --> 108             cated_input = self.dropout(hidden)
#     109             new_hiddens.append(hidden.unsqueeze(0))
#     110             new_cs.append(c.unsqueeze(0))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     578             if name in _buffers:
#     579                 return _buffers[name]
# --> 580         if '_modules' in self.__dict__:
#     581             modules = self.__dict__['_modules']
#     582             if name in modules:
#
# KeyboardInterrupt:

# %%
bleu_3_no_unk, att_score_wo, pred_wo, src_wo = validation_beam_search(encoder_wo_att, decoder_wo_att,dataloader['validate'],en_lang,\
                                                                      zh_lang, 'no_attention',3,verbose=True)
# Out:
# True Sentence: when i was 11 , i remember waking up one morning to the sound of joy in my house .
# Pred Sentence: i was at the age of 12 , and i remember listening to the next day , and the voice was the voice of the music .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: my father was listening to bbc news on his small , gray radio .
# Pred Sentence: my father was a little boy , and he had a lot of PAD and a lot .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: there was a big smile on his face which was unusual then , because the news mostly depressed him .
# Pred Sentence: he &apos;s got a lot of money , and he &apos;s because most of us don &apos;t get to the end of it .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: &quot; the taliban are gone ! &quot; my father shouted .
# Pred Sentence: it was the father of the father of the father .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i didn &apos;t know what it meant , but i could see that my father was very , very happy .
# Pred Sentence: i don &apos;t know what it is . i mean , i mean , it &apos;s pretty good .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: &quot; you can go to a real school now , &quot; he said .
# Pred Sentence: you can go to school , and you &apos;re going to go to school .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: a morning that i will never forget .
# Pred Sentence: i will never forget that .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: a real school .
# Pred Sentence: a school .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: you see , i was six when the taliban took over afghanistan and made it illegal for girls to go to school .
# Pred Sentence: i was 13 years old , and i went to the hospital , and i was in the hospital .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: so for the next five years , i dressed as a boy to escort my older sister , who was no longer allowed to be outside alone , to a secret school .
# Pred Sentence: so , in that moment , i went to school , and i went to school , and my dad was not going to go to school .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: it was the only way we both could be educated .
# Pred Sentence: and this is the only way we &apos;re going to be PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: each day , we took a different route so that no one would suspect where we were going .
# Pred Sentence: so we &apos;re going to get there , and there &apos;s a lot of people in the room , and we PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we would cover our books in grocery bags so it would seem we were just out shopping .
# Pred Sentence: we put it on the table , and we thought , &quot; well , we want to make a house . &quot;
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the school was in a house , more than 100 of us packed in one small living room .
# Pred Sentence: in the office , we &apos;re going to put in a house , and we &apos;re sitting in a PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: it was cozy in winter but extremely hot in summer .
# Pred Sentence: it was too cold , but it was cold .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we all knew we were risking our lives -- the teacher , the students and our parents .
# Pred Sentence: we all know that all of our children and our children , and our teachers are so good .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: from time to time , the school would suddenly be canceled for a week because taliban were suspicious .
# Pred Sentence: and sometimes , sometimes , at the age of the week , the girls were coming back .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we always wondered what they knew about us .
# Pred Sentence: and we always always think that we &apos;re going to go back to the end .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: were we being followed ?
# Pred Sentence: where are we going to go ?
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: do they know where we live ?
# Pred Sentence: do they know what we do ?
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: we were scared , but still , school was where we wanted to be .
# Pred Sentence: we are so bad , but we still have to go to school .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: i was very lucky to grow up in a family where education was prized and daughters were treasured .
# Pred Sentence: i was very lucky , and i was in a family family , and her family .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence
AD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: the exciting thing is that i see students at my school with ambition grabbing at opportunity .
# Pred Sentence: and what i &apos;ve learned is , i &apos;ve been working with my students , and i &apos;ve been working with the kids .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: and i see their parents and their fathers who , like my own , advocate for them , despite and even in the face of daunting opposition .
# Pred Sentence: and i saw them as their father , their father , their father , their father , and they were so scared , and they didn &apos;t know .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: like ahmed . that &apos;s not his real name , and i cannot show you his face , but ahmed is the father of one of my students .
# Pred Sentence: so , for instance , that &apos;s not what i can do with him , but i can &apos;t tell him what he is .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: less than a month ago , he and his daughter were on their way from sola to their village , and they literally missed being killed by a roadside bomb by minutes .
# Pred Sentence: and he sat there , and he sat down in the morning , and he went to the village , and they were going to go to the village .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: as he arrived home , the phone rang , a voice warning him that if he sent his daughter back to school , they would try again .
# Pred Sentence: and he got his hands , and he said , &quot; you know , the next day , the next time you &apos;re going to the the , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: &quot; kill me now , if you wish , &quot; he said , &quot; but i will not ruin my daughter &apos;s future because of your old and backward ideas . &quot;
# Pred Sentence: and if you think about it , you don &apos;t have to say , &quot; but i &apos;m going to be your my daughter , &quot; and my PAD .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: what i &apos;ve come to realize about afghanistan , and this is something that is often dismissed in the west , that behind most of us who succeed is a father who recognizes the value in his daughter and who sees that her success is his success .
# Pred Sentence: and i realized that this was the case of the civil rights movement , and the reason why they came up with this idea was that he was the only person in the world , and he was the father of the father of the father .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: it &apos;s not to say that our mothers aren &apos;t key in our success .
# Pred Sentence: it doesn &apos;t mean that it &apos;s not important for our children .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: in fact , they &apos;re often the initial and convincing negotiators of a bright future for their daughters , but in the context of a society like in afghanistan , we must have the support of men .
# Pred Sentence: in fact , the first time in the family , the the , the , the , the , the , , the , the , the , PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: under the taliban , girls who went to school numbered in the hundreds -- remember , it was illegal .
# Pred Sentence: in the hospital , in the hospital , the girls were not going to go to the . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: but today , more than three million girls are in school in afghanistan .
# Pred Sentence: but today , today , there are more and more girls in the united states .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# True Sentence: afghanistan looks so different from here in america .
# Pred Sentence: and so , there &apos;s a relationship between the united states and the united states .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-e458161a5eab> in <module>()
# ----> 1 bleu_3_no_unk, att_score_wo, pred_wo, src_wo = validation_beam_search(encoder_wo_att, decoder_wo_att,dataloader['validate'],en_lang,                                                                      zh_lang, 'no_attention',3,verbose=True)
#
# <ipython-input-39-15ede751d95b> in validation_beam_search(encoder, decoder, val_dataloader, lang_en, lang_zh, m_type, beam_size, verbose, device, replace_unk)
#      65                 for b in range(beam_size):
#      66                     if not beam_stop_flags[b]:
# ---> 67                         beam_score[0][b] = topv[0][b].item()
#      68                         list_decoder_input[b] = topi_idx[0][b].squeeze().detach().view(-1,1)
#      69                         list_d_outs[b] = copy.deepcopy(prev_d_outs[id_for_hid[0][b]])
#
# KeyboardInterrupt:

# %%
bleu_3_no_unk
# Out:
# []

# %%
bleu_3_unk, att_score_wo, pred_wo, src_wo = validation_beam_search(encoder_wo_att, decoder_wo_att,dataloader['validate'],en_lang,\
                                                                      zh_lang, 'no_attention',3,verbose=False,\
                                                                  replace_unk = True)

# %%
bleu_3_unk
# Out:
# 2.0231176224080625

# %% [markdown]
# # 6. With Attention (Training and Evaluation)

# %%
encoder_w_att = EncoderRNN(zh_lang.n_words,512,512, 1).to(device)
decoder_w_att = AttentionDecoderRNN(en_lang.n_words,512,1024,n_layers=1, attention = True).to(device)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:51: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
# encoder_optimizer = optim.Adam(encoder_wo_att.parameters(), lr = 5e-3)
# decoder_optimizer = optim.Adam(decoder_wo_att.parameters(), lr = 5e-3)
encoder_optimizer = optim.SGD(encoder_w_att.parameters(), lr=0.25,nesterov=True, momentum = 0.99)
enc_scheduler = ReduceLROnPlateau(encoder_optimizer, min_lr=1e-4,factor = 0.5,  patience=0)
decoder_optimizer = optim.SGD(decoder_w_att.parameters(), lr=0.25,nesterov=True, momentum = 0.99)
dec_scheduler = ReduceLROnPlateau(decoder_optimizer, min_lr=1e-4,factor = 0.5,  patience=0)

criterion = nn.CrossEntropyLoss()

# %%
encoder_w_att, decoder_w_att, loss_hist, acc_hist = train_model(encoder_optimizer, decoder_optimizer, encoder_w_att, decoder_w_att, criterion,\
                                            "non_attention", dataloader,en_lang,zh_lang, num_epochs = 15, rm = 0.95,\
                                           enc_scheduler = enc_scheduler, dec_scheduler = dec_scheduler)
# Out:
# epoch 0 train loss = 2.460211066216973, time = 1795.6972987651825
# epoch 0 val_train loss = 3.461334352735297, time = 7.081878185272217
# validation BLEU =  3.736753008761299
# ==================================================
# epoch 1 train loss = 1.8171819930790505, time = 1794.0977544784546
# epoch 1 val_train loss = 3.1730011345184956, time = 7.033458232879639
# validation BLEU =  5.194245866410646
# ==================================================
# epoch 2 train loss = 1.5941304733316928, time = 1791.451252937317
# epoch 2 val_train loss = 3.2067840133367502, time = 7.0042548179626465
# validation BLEU =  7.439363102350998
# ==================================================
# epoch 3 train loss = 1.4255019258529478, time = 1788.835521697998
# epoch 3 val_train loss = 3.480915092835816, time = 7.12290096282959
# validation BLEU =  10.866082975011832
# ==================================================
# epoch 4 train loss = 1.3343844063131227, time = 1789.928823709488
# epoch 4 val_train loss = 3.7346753620326187, time = 7.01096510887146
# validation BLEU =  11.887498249998211
# ==================================================
# epoch 5 train loss = 1.2603816894052053, time = 1787.6487514972687
# epoch 5 val_train loss = 3.158858620297994, time = 7.017610549926758
# validation BLEU =  10.05030718539935
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-83d179ff1dca> in <module>()
# ----> 1 encoder_w_att, decoder_w_att, loss_hist, acc_hist = train_model(encoder_optimizer, decoder_optimizer, encoder_w_att, decoder_w_att, criterion,                                            "non_attention", dataloader,en_lang,zh_lang, num_epochs = 15, rm = 0.95,                                           enc_scheduler = enc_scheduler, dec_scheduler = dec_scheduler)
#
# <ipython-input-24-86a972ce5d37> in train_model(encoder_optimizer, decoder_optimizer, encoder, decoder, loss_fun, m_type, dataloader, en_lang, zh_lang, num_epochs, val_every, train_bleu_every, clip, rm, enc_scheduler, dec_scheduler, enc_dec_fn, val_fn)
#      31                     out = enc_dec_fn(encoder,decoder,encoder_i,decoder_i,src_len,tar_len,rand_num=rm,val = True )
#      32                 else:
# ---> 33                     out = enc_dec_fn(encoder,decoder,encoder_i,decoder_i,src_len,tar_len,rand_num=rm,val = False )
#      34                 N = decoder_i.size(0)
#      35                 loss = loss_fun(out.float(), decoder_i.long())
#
# <ipython-input-20-9cf137aef858> in encode_decode(encoder, decoder, data_en, data_de, src_len, tar_len, rand_num, val)
#      14             d_out = []
#      15             for i in range(max_tar_len_batch):
# ---> 16                 out_vocab, prev_output,prev_hiddens, prev_cs, attention_score = decoder(decoder_input,prev_output,                                                                                         prev_hiddens,prev_cs, en_out,                                                                                        src_len)
#      17                 d_out.append(out_vocab.unsqueeze(-1))
#      18                 decoder_input = data_de[:,i].view(-1,1)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-17-99cef6e9fb2f> in forward(self, dec_input, context_vector, prev_hiddens, prev_cs, encoder_outputs, src_len)
#     114         # apply attention using the last layer's hidden state
#     115         if self.att_layer is not None:
# --> 116             out, attn_score = self.att_layer(hidden, encoder_outputs, src_len)
#     117         else:
#     118             out = hidden
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-17-99cef6e9fb2f> in forward(self, hidden, encoder_outs, src_lens)
#      66         x = self.l1(hidden)
#      67         att_score = (encoder_outs.transpose(0,1) * x.unsqueeze(0)).sum(dim = 2)
# ---> 68         seq_mask = sequence_mask(src_lens, max_len = max(src_lens).item(), device = self.device).transpose(0,1)
#      69         masked_att = seq_mask*att_score
#      70         masked_att[masked_att==0] = -1e10
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in <lambda>(i)
#     425                           'iterations executed (and might lead to errors or silently give '
#     426                           'incorrect results).', category=RuntimeWarning)
# --> 427         return iter(imap(lambda i: self[i], range(self.size(0))))
#     428
#     429     def __hash__(self):
#
# KeyboardInterrupt:

# %%
torch.save(encoder_w_att.state_dict(), 'lstm_w_att_enc_1_layer.pth')
torch.save(decoder_w_att.state_dict(), 'lstm_w_att_dec_1_layer.pth')

# %% [markdown]
# ## Evaluation using BLEU with beam size 10

# %%
bleu_10_no_unk, att_score_w, pred_w, src_w = validation_beam_search(encoder_w_att, decoder_w_att,dataloader['validate'],en_lang,\
                                                                      zh_lang, 'attention',10,verbose=True)
# Out:
# Source Sentence: 我 11 岁 那年 记得 得有 一天 早晨 醒来 听见 家里 有 愉悦 的 声音
# True Sentence: when i was 11 , i remember waking up one morning to the sound of joy in my house .
# Pred Sentence: i was 11 years old , and i remember that one morning , there was a pleasure of pleasure in the morning .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 我 的 父亲 在 用 他 的 灰色 小 收音 收音机 听 bbc 新闻
# True Sentence: my father was listening to bbc news on his small , gray radio .
# Pred Sentence: my father was listening to the bbc news in his gray little radio .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 他 面带 UKN UKN 笑容 这 很少 少见 因为 大部 大部分 部分 的 新闻 都 只 会 使 他 沮丧
# True Sentence: there was a big smile on his face which was unusual then , because the news mostly depressed him .
# Pred Sentence: and he was smiling , and it was very rare , because most of the news was only UKN .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 塔利 塔利班 走 了 父亲 大声 叫 着
# True Sentence: &quot; the taliban are gone ! &quot; my father shouted .
# Pred Sentence: the taliban took his father out loud .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 

# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 而 你 唯一 能够 守护 护住 的 东西 就是 这里 如果 我们 不得 不得不 不靠 卖 血 来 支付 你 的 学费 我们 会 毫不 毫不犹豫 犹豫
# True Sentence: but the one thing that will always remain with you is what is here , and if we have to sell our blood to pay your school fees , we will .
# Pred Sentence: and the only thing you can do is if you had to sell the blood , and if we had to sell blood to pay your school , we would have no mistakes .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 即便 即便如此 如此 你 还是 不想 继续 吗
# True Sentence: so do you still not want to continue ? &quot;
# Pred Sentence: even so , do you want to continue ?
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 如今 我 22 岁
# True Sentence: today i am 22 .
# Pred Sentence: now , i &apos;m 22 years old .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 我 所 成长 的 国家 被 几十 几十年 十年 的 战争 所 摧毁
# True Sentence: i was raised in a country that has been destroyed by decades of war .
# Pred Sentence: the country i grew up has destroyed the destruction of decades .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 我 这个 年龄 的 女性 中 高中 高中毕业 毕业 的 人数 UKN 不到 6 如果 不是 我家 家人 的 坚持 我 也 会 像 绝大 绝大多数 大多 大多数 多数 数人 一样
# True Sentence: fewer than six percent of women my age have made it beyond high school , and had my family not been so committed to my education , i would be one of them .
# Pred Sentence: the number of women i &apos;ve graduated from high school graduates don &apos;t get six percent , and if not my family insisted , i will be the most majority of people .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Source Sentence: 而 如今 我 已经 是 一名 自豪 的 UKN 学院 的 毕业 毕业生 业生
# True Sentence: instead , i stand here a proud graduate of middlebury college .
# Pred Sentence: and now i &apos;m a proud student .
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-111c11ba4f1d> in <module>()
# ----> 1 bleu_10_no_unk, att_score_w, pred_w, src_w = validation_beam_search(encoder_w_att, decoder_w_att,dataloader['validate'],en_lang,                                                                      zh_lang, 'attention',10,verbose=True)
#
# <ipython-input-34-13f4dc5fbb19> in validation_beam_search(encoder, decoder, val_dataloader, lang_en, lang_zh, m_type, beam_size, verbose, device, replace_unk)
#      54                 for b in range(beam_size):
#      55                     if not beam_stop_flags[b]:
# ---> 56                         beam_out_vocab[b], temp_out[b], temp_hid[b], temp_c[b], temp_attention_score[b] =                            decoder(list_decoder_input[b],list_prev_output[b],list_prev_hiddens[b],list_prev_cs[b],                                    en_out,src_len)
#      57                         beam_out_vocab[b] = beam_out_vocab[b] + beam_score[0][b]
#      58                     if beam_stop_flags[b]:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-17-99cef6e9fb2f> in forward(self, dec_input, context_vector, prev_hiddens, prev_cs, encoder_outputs, src_len)
#      96     def forward(self, dec_input,context_vector, prev_hiddens,prev_cs,encoder_outputs,src_len):
#      97         bsz = dec_input.size(0)
# ---> 98         output = self.embedding(dec_input)
#      99         output = self.dropout(output)
#     100         if self.att_layer is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     112         return F.embedding(
#     113             input, self.weight, self.padding_idx, self.max_norm,
# --> 114             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     115
#     116     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1482         # remove once script supports set_grad_enabled
#    1483         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1484     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1485
#    1486
#
# KeyboardInterrupt:

# %%
bleu_10_unk, att_score_w, pred_w, src_wo = validation_beam_search(encoder_wo_att, decoder_wo_att,dataloader['validate'],en_lang,\
                                                                      zh_lang, 'attention',10,verbose=False,\
                                                                   replace_unk = True)

# %% [markdown]
# ## plotting Attention maps

# %%
n = 0
draw(att_score_wo[n],pred_wo[n],src_wo[n])

# %%
att_score_wo
# Out:
# []
